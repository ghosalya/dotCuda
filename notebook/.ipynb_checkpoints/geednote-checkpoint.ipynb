# %% [markdown]
# # Training Session

# %%
import pickle

from build_vocab import *
from build_answers import *

# %%
# train2014
answers_path = '/home/ubuntu/dotCuda/notebook/answers.pkl'
with open(answers_path, 'rb') as f:
    answers = pickle.load(f)

vocab_path = '../../dotCuda/notebook/vocab.pkl'
with open(vocab_path, 'rb') as f:
    vocab = pickle.load(f)
    
# val2014
answers_path = '/home/ubuntu/dotCuda/notebook/valanswers.pkl'
with open(answers_path, 'rb') as f:
    valanswers = pickle.load(f)

vocab_path = '../../dotCuda/notebook/valvocab.pkl'
with open(vocab_path, 'rb') as f:
    valvocab = pickle.load(f)

# %%
from dataset import *

train_dataset = COCODataset(vocab=vocab, answers=answers)
val_dataset = COCODataset(vocab=valvocab, answers=valanswers)
# Out:
# loading VQA annotations and questions into memory...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9f37d7b8>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 324, in _shutdown_workers
#     q.put(None)
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 355, in put
#     self._writer.send_bytes(obj)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# OSError: [Errno 9] Bad file descriptor
# 0:00:11.178591
# creating index...
# index created!
# loading VQA annotations and questions into memory...
# 0:00:18.283768
# creating index...
# index created!

# %% [markdown]
# ### Network Model

# %%
# import network 
from network_v5b import *

# %%
import torch
device = torch.device('cuda')

vocab_size = len(vocab)
model = ConcatNet(vocab_size).to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet152-b121ed2d.pth" to /home/ubuntu/.torch/models/resnet152-b121ed2d.pth
# 100.0%

# %% [markdown]
# ### Trainer Class

# %%
# import trainer
from trainer import VQATrainer

trainer = VQATrainer(model, device)

# %% [markdown]
# ### Train! - on frozen resnet

# %%
trained_model, statistics = trainer.train(train_dataset, val_dataset, save_every=50000, learnrate=10, collate_fn=collate, e_break=1, epoch=1000, val_size=10)
# Out:
# Epoch 0 of 1000
#   Training...
#    >> Epoch finished with loss 64.05096 and accuracy 0.000 in 0.4809s
#   Validating...
#    >> Epoch finished with loss 64.05096 and accuracy 0.000 in 0.7687s
# Epoch 1 of 1000
#   Training...
#    >> Epoch finished with loss 64.05095 and accuracy 0.000 in 0.6942s
#   Validating...
#    >> Epoch finished with loss 64.05094 and accuracy 0.000 in 0.8724s
# Epoch 2 of 1000
#   Training...
#    >> Epoch finished with loss 64.05094 and accuracy 0.000 in 0.7326s
#   Validating...
#    >> Epoch finished with loss 64.05093 and accuracy 0.000 in 0.7070s
# Epoch 3 of 1000
#   Training...
#    >> Epoch finished with loss 64.05092 and accuracy 0.000 in 0.8758s
#   Validating...
#    >> Epoch finished with loss 64.05093 and accuracy 0.000 in 0.9069s
# Epoch 4 of 1000
#   Training...
#    >> Epoch finished with loss 64.05090 and accuracy 0.000 in 0.9045s
#   Validating...
#    >> Epoch finished with loss 64.05093 and accuracy 0.000 in 0.8677s
# Epoch 5 of 1000
#   Training...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9f38cdd8>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 64.05088 and accuracy 0.000 in 0.7155s
#   Validating...
#    >> Epoch finished with loss 64.05092 and accuracy 0.000 in 0.8705s
# Epoch 6 of 1000
#   Training...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9f38cdd8>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 64.05088 and accuracy 0.000 in 0.6028s
#   Validating...
#    >> Epoch finished with loss 64.05091 and accuracy 0.000 in 0.7413s
# Epoch 7 of 1000
#   Training...
#    >> Epoch finished with loss 64.05086 and accuracy 0.000 in 1.0031s
#   Validating...
#    >> Epoch finished with loss 64.05091 and accuracy 0.000 in 0.9667s
# Epoch 8 of 1000
#   Training...
#    >> Epoch finished with loss 64.05085 and accuracy 0.000 in 0.7207s
#   Validating...
#    >> Epoch finished with loss 64.05090 and accuracy 0.000 in 0.8854s
# Epoch 9 of 1000
#   Training...
#    >> Epoch finished with loss 64.05084 and accuracy 0.000 in 0.9851s
#   Validating...
#    >> Epoch finished with loss 64.05090 and accuracy 0.000 in 0.7840s
# Epoch 10 of 1000
#   Training...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d586cc0>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 64.05082 and accuracy 0.000 in 0.7282s
#   Validating...
#    >> Epoch finished with loss 64.05090 and accuracy 0.000 in 0.8607s
# Epoch 11 of 1000
#   Training...
#    >> Epoch finished with loss 64.05080 and accuracy 0.000 in 0.8986s
#   Validating...
#    >> Epoch finished with loss 64.05089 and accuracy 0.000 in 0.8951s
# Epoch 12 of 1000
#   Training...
#    >> Epoch finished with loss 64.05078 and accuracy 0.000 in 0.7634s
#   Validating...
#    >> Epoch finished with loss 64.05087 and accuracy 0.000 in 0.8852s
# Epoch 13 of 1000
#   Training...
#    >> Epoch finished with loss 64.05077 and accuracy 0.000 in 0.8776s
#   Validating...
#    >> Epoch finished with loss 64.05087 and accuracy 0.000 in 0.7824s
# Epoch 14 of 1000
#   Training...
#    >> Epoch finished with loss 64.05074 and accuracy 0.000 in 0.7941s
#   Validating...
#    >> Epoch finished with loss 64.05087 and accuracy 0.000 in 0.8559s
# Epoch 15 of 1000
#   Training...
#    >> Epoch finished with loss 64.05071 and accuracy 0.000 in 0.7955s
#   Validating...
#    >> Epoch finished with loss 64.05086 and accuracy 0.000 in 0.7554s
# Epoch 16 of 1000
#   Training...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9f38cf28>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 64.05070 and accuracy 0.000 in 0.7000s
#   Validating...
#    >> Epoch finished with loss 64.05086 and accuracy 0.000 in 0.7278s
# Epoch 17 of 1000
#   Training...
#    >> Epoch finished with loss 64.05067 and accuracy 0.000 in 0.7278s
#   Validating...
#    >> Epoch finished with loss 64.05084 and accuracy 0.000 in 0.8848s
# Epoch 18 of 1000
#   Training...
#    >> Epoch finished with loss 64.05065 and accuracy 0.000 in 0.7589s
#   Validating...
#    >> Epoch finished with loss 64.05083 and accuracy 0.000 in 0.8982s
# Epoch 19 of 1000
#   Training...
#    >> Epoch finished with loss 64.05064 and accuracy 0.000 in 0.8834s
#   Validating...
#    >> Epoch finished with loss 64.05083 and accuracy 0.000 in 0.8709s
# Epoch 20 of 1000
#   Training...
#    >> Epoch finished with loss 64.05060 and accuracy 0.000 in 0.7200s
#   Validating...
#    >> Epoch finished with loss 64.05082 and accuracy 0.000 in 0.8241s
# Epoch 21 of 1000
#   Training...
#    >> Epoch finished with loss 64.05058 and accuracy 0.000 in 0.8897s
#   Validating...
#    >> Epoch finished with loss 64.05081 and accuracy 0.000 in 0.8248s
# Epoch 22 of 1000
#   Training...
#    >> Epoch finished with loss 64.05058 and accuracy 0.000 in 0.8492s
#   Validating...
#    >> Epoch finished with loss 64.05080 and accuracy 0.000 in 0.7139s
# Epoch 23 of 1000
#   Training...
#    >> Epoch finished with loss 64.05054 and accuracy 0.000 in 0.8579s
#   Validating...
#    >> Epoch finished with loss 64.05080 and accuracy 0.000 in 0.7306s
# Epoch 24 of 1000
#   Training...
#    >> Epoch finished with loss 64.05049 and accuracy 0.000 in 0.7742s
#   Validating...
#    >> Epoch finished with loss 64.05077 and accuracy 0.000 in 0.8576s
# Epoch 25 of 1000
#   Training...
#    >> Epoch finished with loss 64.05045 and accuracy 0.000 in 0.7461s
#   Validating...
#    >> Epoch finished with loss 64.05077 and accuracy 0.000 in 0.7255s
# Epoch 26 of 1000
#   Training...
#    >> Epoch finished with loss 64.05043 and accuracy 0.000 in 0.8063s
#   Validating...
#    >> Epoch finished with loss 64.05076 and accuracy 0.000 in 0.7319s
# Epoch 27 of 1000
#   Training...
#    >> Epoch finished with loss 64.05042 and accuracy 0.000 in 0.8948s
#   Validating...
#    >> Epoch finished with loss 64.05074 and accuracy 0.000 in 0.9380s
# Epoch 28 of 1000
#   Training...
#    >> Epoch finished with loss 64.05036 and accuracy 0.000 in 0.9153s
#   Validating...
#    >> Epoch finished with loss 64.05073 and accuracy 0.000 in 0.7069s
# Epoch 29 of 1000
#   Training...
#    >> Epoch finished with loss 64.05033 and accuracy 0.000 in 0.9062s
#   Validating...
#    >> Epoch finished with loss 64.05072 and accuracy 0.000 in 0.7501s
# Epoch 30 of 1000
#   Training...
#    >> Epoch finished with loss 64.05029 and accuracy 0.000 in 0.7783s
#   Validating...
#    >> Epoch finished with loss 64.05070 and accuracy 0.000 in 0.8657s
# Epoch 31 of 1000
#   Training...
#    >> Epoch finished with loss 64.05022 and accuracy 0.000 in 0.8996s
#   Validating...
#    >> Epoch finished with loss 64.05068 and accuracy 0.000 in 0.8886s
# Epoch 32 of 1000
#   Training...
#    >> Epoch finished with loss 64.05019 and accuracy 0.000 in 0.8847s
#   Validating...
#    >> Epoch finished with loss 64.05067 and accuracy 0.000 in 0.8819s
# Epoch 33 of 1000
#   Training...
#    >> Epoch finished with loss 64.05016 and accuracy 0.000 in 0.7605s
#   Validating...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d588e10>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 64.05064 and accuracy 0.000 in 0.7858s
# Epoch 34 of 1000
#   Training...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9f38cdd8>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 64.05006 and accuracy 0.000 in 0.8298s
#   Validating...
#    >> Epoch finished with loss 64.05063 and accuracy 0.000 in 0.8359s
# Epoch 35 of 1000
#   Training...
#    >> Epoch finished with loss 64.05001 and accuracy 0.000 in 0.9140s
#   Validating...
#    >> Epoch finished with loss 64.05060 and accuracy 0.000 in 0.8820s
# Epoch 36 of 1000
#   Training...
#    >> Epoch finished with loss 64.04994 and accuracy 0.000 in 0.9212s
#   Validating...
#    >> Epoch finished with loss 64.05058 and accuracy 0.000 in 0.7389s
# Epoch 37 of 1000
#   Training...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d5860b8>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 737, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
#    >> Epoch finished with loss 64.04987 and accuracy 0.000 in 0.6431s
#   Validating...
#    >> Epoch finished with loss 64.05054 and accuracy 0.000 in 0.9833s
# Epoch 38 of 1000
#   Training...
#    >> Epoch finished with loss 64.04974 and accuracy 0.000 in 0.7904s
#   Validating...
#    >> Epoch finished with loss 64.05052 and accuracy 0.000 in 0.8565s
# Epoch 39 of 1000
#   Training...
#    >> Epoch finished with loss 64.04967 and accuracy 0.000 in 0.9398s
#   Validating...
#    >> Epoch finished with loss 64.05048 and accuracy 0.000 in 0.7537s
# Epoch 40 of 1000
#   Training...
#    >> Epoch finished with loss 64.04961 and accuracy 0.000 in 0.7752s
#   Validating...
#    >> Epoch finished with loss 64.05045 and accuracy 0.000 in 0.9081s
# Epoch 41 of 1000
#   Training...
#    >> Epoch finished with loss 64.04949 and accuracy 0.000 in 0.7517s
#   Validating...
#    >> Epoch finished with loss 64.05041 and accuracy 0.000 in 0.8668s
# Epoch 42 of 1000
#   Training...
#    >> Epoch finished with loss 64.04932 and accuracy 0.000 in 0.7472s
#   Validating...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9f38cdd8>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 64.05035 and accuracy 0.000 in 0.6150s
# Epoch 43 of 1000
#   Training...
#    >> Epoch finished with loss 64.04916 and accuracy 0.000 in 0.9439s
#   Validating...
#    >> Epoch finished with loss 64.05029 and accuracy 0.000 in 0.9126s
# Epoch 44 of 1000
#   Training...
#    >> Epoch finished with loss 64.04897 and accuracy 0.000 in 0.7661s
#   Validating...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d5818d0>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 58, in detach
#     return reduction.recv_handle(conn)
#   File "/usr/lib/python3.5/multiprocessing/reduction.py", line 181, in recv_handle
#     return recvfds(s, 1)[0]
#   File "/usr/lib/python3.5/multiprocessing/reduction.py", line 152, in recvfds
#     msg, ancdata, flags, addr = sock.recvmsg(1, socket.CMSG_LEN(bytes_size))
# ConnectionResetError: [Errno 104] Connection reset by peer
#    >> Epoch finished with loss 64.05022 and accuracy 0.000 in 0.7702s
# Epoch 45 of 1000
#   Training...
#    >> Epoch finished with loss 64.04875 and accuracy 0.000 in 0.8293s
#   Validating...
#    >> Epoch finished with loss 64.05013 and accuracy 0.000 in 0.7804s
# Epoch 46 of 1000
#   Training...
#    >> Epoch finished with loss 64.04848 and accuracy 0.000 in 0.7413s
#   Validating...
#    >> Epoch finished with loss 64.05002 and accuracy 0.000 in 0.8847s
# Epoch 47 of 1000
#   Training...
#    >> Epoch finished with loss 64.04799 and accuracy 0.000 in 0.7549s
#   Validating...
#    >> Epoch finished with loss 64.04987 and accuracy 0.000 in 0.8895s
# Epoch 48 of 1000
#   Training...
#    >> Epoch finished with loss 64.04751 and accuracy 0.000 in 0.7270s
#   Validating...
#    >> Epoch finished with loss 64.04966 and accuracy 0.000 in 0.8738s
# Epoch 49 of 1000
#   Training...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d586f98>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 737, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
#    >> Epoch finished with loss 64.04651 and accuracy 0.000 in 0.8027s
#   Validating...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d581240>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 737, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
#    >> Epoch finished with loss 64.04931 and accuracy 0.000 in 0.7400s
# Epoch 50 of 1000
#   Training...
#    >> Epoch finished with loss 64.04473 and accuracy 0.000 in 0.8685s
#   Validating...
#    >> Epoch finished with loss 64.04861 and accuracy 0.000 in 0.8608s
# Epoch 51 of 1000
#   Training...
#    >> Epoch finished with loss 64.04201 and accuracy 0.000 in 0.7806s
#   Validating...
#    >> Epoch finished with loss 64.04677 and accuracy 0.000 in 0.9425s
# Epoch 52 of 1000
#   Training...
#    >> Epoch finished with loss 64.03311 and accuracy 0.000 in 0.8872s
#   Validating...
#    >> Epoch finished with loss 64.03270 and accuracy 0.000 in 0.8747s
# Epoch 53 of 1000
#   Training...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d588b70>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 63.88140 and accuracy 0.000 in 0.5885s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.8981s
# Epoch 54 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.8916s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.9667s
# Epoch 55 of 1000
#   Training...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d588390>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.6730s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.7763s
# Epoch 56 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7708s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.8827s
# Epoch 57 of 1000
#   Training...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d588438>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7046s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.7051s
# Epoch 58 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.8890s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.7582s
# Epoch 59 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.9308s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.7379s
# Epoch 60 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7717s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.9188s
# Epoch 61 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.8764s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.8651s
# Epoch 62 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.8730s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.7263s
# Epoch 63 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.9123s
#   Validating...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d586198>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.5894s
# Epoch 64 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.8708s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.8084s
# Epoch 65 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7915s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.8932s
# Epoch 66 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.9365s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.7721s
# Epoch 67 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7357s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.7709s
# Epoch 68 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.9733s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.8178s
# Epoch 69 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.9203s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.9473s
# Epoch 70 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.9088s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.7104s
# Epoch 71 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.8751s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.8691s
# Epoch 72 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.8921s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.8667s
# Epoch 73 of 1000
#   Training...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d588cc0>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7585s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.9730s
# Epoch 74 of 1000
#   Training...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9f38ccf8>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 737, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7276s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.9467s
# Epoch 75 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.8282s
#   Validating...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9f38ce48>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.7188s
# Epoch 76 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7949s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.7321s
# Epoch 77 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7696s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.8791s
# Epoch 78 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.9063s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.7289s
# Epoch 79 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.8481s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.8728s
# Epoch 80 of 1000
#   Training...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d588c18>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.6216s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.7703s
# Epoch 81 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.9576s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.7769s
# Epoch 82 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.9534s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.8718s
# Epoch 83 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.9146s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.7261s
# Epoch 84 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.8902s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.9211s
# Epoch 85 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7892s
#   Validating...
# ...
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 58, in detach
#     return reduction.recv_handle(conn)
#   File "/usr/lib/python3.5/multiprocessing/reduction.py", line 181, in recv_handle
#     return recvfds(s, 1)[0]
#   File "/usr/lib/python3.5/multiprocessing/reduction.py", line 152, in recvfds
#     msg, ancdata, flags, addr = sock.recvmsg(1, socket.CMSG_LEN(bytes_size))
# ConnectionResetError: [Errno 104] Connection reset by peer
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.5610s
# Epoch 241 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.8753s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.8766s
# Epoch 242 of 1000
#   Training...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9f38cf98>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7549s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.8761s
# Epoch 243 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.9029s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.7645s
# Epoch 244 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7701s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.7002s
# Epoch 245 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.9088s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.8680s
# Epoch 246 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7413s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.7298s
# Epoch 247 of 1000
#   Training...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d5817f0>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7130s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.8963s
# Epoch 248 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.9238s
#   Validating...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9f38ce80>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.7158s
# Epoch 249 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.9568s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.8718s
# Epoch 250 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.8888s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.9371s
# Epoch 251 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.9879s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.7964s
# Epoch 252 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.8885s
#   Validating...
#    >> Epoch finished with loss 64.05553 and accuracy 0.000 in 0.7190s
# Epoch 253 of 1000
#   Training...
# Process Process-2032:
# Process Process-2031:
# Process Process-2029:
# Process Process-2030:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 57, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 57, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 57, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 57, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/ubuntu/dotCuda/notebook/dataset.py", line 50, in __getitem__
#     image = self.transform(image)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 57, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 57, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/ubuntu/dotCuda/notebook/dataset.py", line 48, in __getitem__
#     image = Image.open(os.path.join(self.imgDir, path)).convert('RGB')
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 57, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 57, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torchvision/transforms/transforms.py", line 49, in __call__
#     img = t(img)
#   File "/home/ubuntu/dotCuda/notebook/dataset.py", line 48, in __getitem__
#     image = Image.open(os.path.join(self.imgDir, path)).convert('RGB')
#   File "/usr/local/lib/python3.5/dist-packages/PIL/Image.py", line 879, in convert
#     self.load()
#   File "/usr/local/lib/python3.5/dist-packages/PIL/Image.py", line 879, in convert
#     self.load()
#   File "/home/ubuntu/dotCuda/notebook/dataset.py", line 48, in __getitem__
#     image = Image.open(os.path.join(self.imgDir, path)).convert('RGB')
#   File "/usr/local/lib/python3.5/dist-packages/PIL/ImageFile.py", line 231, in load
#     n, err_code = decoder.decode(b)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torchvision/transforms/transforms.py", line 175, in __call__
#     return F.resize(img, self.size, self.interpolation)
# KeyboardInterrupt
#   File "/usr/local/lib/python3.5/dist-packages/PIL/ImageFile.py", line 231, in load
#     n, err_code = decoder.decode(b)
#   File "/usr/local/lib/python3.5/dist-packages/PIL/Image.py", line 879, in convert
#     self.load()
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torchvision/transforms/functional.py", line 200, in resize
#     return img.resize((ow, oh), interpolation)
#   File "/usr/local/lib/python3.5/dist-packages/PIL/Image.py", line 1749, in resize
#     return self._new(self.im.resize(size, resample, box))
# KeyboardInterrupt
#   File "/usr/local/lib/python3.5/dist-packages/PIL/ImageFile.py", line 231, in load
#     n, err_code = decoder.decode(b)
# KeyboardInterrupt
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-8-f755bce09112>", line 1, in <module>
#     trained_model, statistics = trainer.train(train_dataset, val_dataset, save_every=50000, learnrate=10, collate_fn=collate, e_break=1, epoch=1000)
#   File "/home/ubuntu/dotCuda/notebook/trainer.py", line 46, in train
#     self.model, train_loss, train_acc = self.train_epoch(train_loader, optimizer=sgd_optimizer, e_break=e_break)
#   File "/home/ubuntu/dotCuda/notebook/trainer.py", line 85, in train_epoch
#     outputs = self.model(image, question)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/nn/modules/module.py", line 491, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/ubuntu/dotCuda/notebook/network_v5b.py", line 93, in forward
#     cache = self.qns_channel.init_cache(batch=questions.batch_sizes[0])
#   File "/home/ubuntu/dotCuda/notebook/network_v5b.py", line 67, in init_cache
#     h0, c0 = h0.cuda(), c0.cuda()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 1863, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/ultratb.py", line 311, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/ultratb.py", line 345, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.5/inspect.py", line 1453, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.5/inspect.py", line 1410, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.5/inspect.py", line 672, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.5/inspect.py", line 709, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 178, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 25820) exited unexpectedly with exit code 1.
# ---------------------------------------------------------------------------

# %%
# import pickle

# with open('stats.st', 'rb') as statfile:
#     statistic = pickle.load(statfile)
    
# #print(statistic)

# #trainer.plot_over_epoch()
# from trainer import VQATrainer

# trainer = VQATrainer(None, None)
# trainer.statistics = statistic

trainer.plot_over_epoch()

# %%
from torchvision import transforms
import matplotlib.pyplot as plt
import random


device = torch.device('cuda')
vocab_size = len(vocab)
model = ConcatNet(vocab_size).to(device)

state_dict = torch.load('model_epoch0.pt')
model.load_state_dict(state_dict)

# %%
import random

for idx in [random.randint(0, 4e5) for i in range(8)]:
    print('\nqn no', idx)
    qns, img, ans = collate([train_dataset[idx]])
    output = model(img.cuda(), qns.long().cuda())
    _, pred = output.topk(10)
    # print(qns, pred)

    #pil_img = transforms.ToPILImage()(img)
    #plt.imshow(pil_img)
    qnss = ' '.join([vocab.idx2word[i.item()] for i in qns.data])
    ans_ = ' / '.join([answers.idx2ans[j.item()] for j in pred[0]])
    lbl = ' - '.join([answers.idx2ans[k.item()] for k in ans[0]])
    print('question:', qnss)
    print('answer:', ans_)
    print('label:', lbl)
    ans = [a.cuda() for a in ans]
    print('accuracy', trainer.accuracy_fn(output.detach(), ans))
    print('loss', trainer.get_losses(output, ans))
# Out:
# qn no 372891
# question: <start> does this animal look like it is smiling ? <end>
# answer: yes / no / 1 / 2 / cabinets / brushing her teeth / shower / surprised / trucks / yard
# label: no - no - no - no - no - no - no - no - no - no
# accuracy 0.0
# loss tensor(8.0067, device='cuda:0')
#
# qn no 153688
# question: <start> can you see tree in the picture ? <end>
# answer: yes / no / 1 / 2 / cabinets / brushing her teeth / surprised / shower / yard / current
# label: no - no - no - no - no - no - no - no - no - no
# accuracy 0.0
# loss tensor(8.0069, device='cuda:0')
#
# qn no 363437
# question: <start> is there wind ? <end>
# answer: yes / no / 1 / 2 / cabinets / brushing her teeth / shower / yard / current / 11
# label: no - no - no - no - no - no - in air - yes - yes - no
# accuracy 0.6666666666666666
# loss tensor(7.8069, device='cuda:0')
#
# qn no 319409
# question: <start> in what decade was this photo taken ? <end>
# answer: yes / no / 1 / 2 / cabinets / brushing her teeth / shower / surprised / birthday cake / 11
# label:
# accuracy 0.0
# loss None
#
# qn no 197611
# question: <start> how many zebra 's are there ? <end>
# answer: yes / no / 1 / 2 / cabinets / brushing her teeth / shower / surprised / cups / natural
# label: lot - 32 - 13 - 40 - 100 - 12 - 100 - lot - 40
# accuracy 0.0
# loss tensor(8.0069, device='cuda:0')
#
# qn no 246500
# question: <start> are there footprints in the snow ? <end>
# answer: yes / no / 1 / 2 / cabinets / brushing her teeth / shower / surprised / birthday cake / 11
# label: yes - yes - yes - yes - yes - yes - yes - yes - yes - no
# accuracy 1.0
# loss tensor(7.1071, device='cuda:0')
#
# qn no 147104
# question: <start> is the puppy wearing a leash ? <end>
# answer: yes / no / 1 / 2 / shower / cabinets / brushing her teeth / surprised / birthday cake / 11
# label: yes - yes - yes - no - yes - yes - yes - no - yes - yes
# accuracy 1.0
# loss tensor(7.2070, device='cuda:0')
#
# qn no 330420
# question: <start> are the man 's feet sandy ? <end>
# answer: yes / no / 1 / 2 / cabinets / brushing her teeth / shower / surprised / under / auburn
# label: yes - yes - yes - yes - yes - yes - yes - yes - yes - yes
# accuracy 1.0
# loss tensor(7.0071, device='cuda:0')

# %% [markdown]
# ### Train - on unfrozen resnet

# %%
model = ConcatNet(vocab_size, freeze_resnet=False).to(device)
trainer = VQATrainer(model, device)

# %%
trained_model, statistics = trainer.train(train_dataset, val_dataset, save_every=50000, learnrate=10, collate_fn=collate, e_break=1, epoch=1000)
# Out:
# Epoch 0 of 1000
#   Training...
#    >> Epoch finished with loss 64.05096 and accuracy 0.000 in 1.0517s
#   Validating...
#    >> Epoch finished with loss 64.05092 and accuracy 0.000 in 0.8228s
# Epoch 1 of 1000
#   Training...
#    >> Epoch finished with loss 64.05093 and accuracy 0.000 in 1.1600s
#   Validating...
#    >> Epoch finished with loss 64.05092 and accuracy 0.000 in 0.7493s
# Epoch 2 of 1000
#   Training...
#    >> Epoch finished with loss 64.05092 and accuracy 0.000 in 1.1299s
#   Validating...
#    >> Epoch finished with loss 64.05092 and accuracy 0.000 in 0.8171s
# Epoch 3 of 1000
#   Training...
#    >> Epoch finished with loss 64.05089 and accuracy 0.000 in 1.3323s
#   Validating...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9f38cbe0>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 58, in detach
#     return reduction.recv_handle(conn)
#   File "/usr/lib/python3.5/multiprocessing/reduction.py", line 181, in recv_handle
#     return recvfds(s, 1)[0]
#   File "/usr/lib/python3.5/multiprocessing/reduction.py", line 152, in recvfds
#     msg, ancdata, flags, addr = sock.recvmsg(1, socket.CMSG_LEN(bytes_size))
# ConnectionResetError: [Errno 104] Connection reset by peer
#    >> Epoch finished with loss 64.05091 and accuracy 0.000 in 0.5866s
# Epoch 4 of 1000
#   Training...
#    >> Epoch finished with loss 64.05090 and accuracy 0.000 in 1.2788s
#   Validating...
#    >> Epoch finished with loss 64.05090 and accuracy 0.000 in 0.7286s
# Epoch 5 of 1000
#   Training...
#    >> Epoch finished with loss 64.05087 and accuracy 0.000 in 1.2672s
#   Validating...
#    >> Epoch finished with loss 64.05090 and accuracy 0.000 in 0.7471s
# Epoch 6 of 1000
#   Training...
#    >> Epoch finished with loss 64.05087 and accuracy 0.000 in 1.2894s
#   Validating...
#    >> Epoch finished with loss 64.05090 and accuracy 0.000 in 0.7348s
# Epoch 7 of 1000
#   Training...
#    >> Epoch finished with loss 64.05084 and accuracy 0.000 in 1.2970s
#   Validating...
#    >> Epoch finished with loss 64.05088 and accuracy 0.000 in 0.7481s
# Epoch 8 of 1000
#   Training...
#    >> Epoch finished with loss 64.05083 and accuracy 0.000 in 1.3188s
#   Validating...
#    >> Epoch finished with loss 64.05088 and accuracy 0.000 in 0.7472s
# Epoch 9 of 1000
#   Training...
#    >> Epoch finished with loss 64.05080 and accuracy 0.000 in 1.3210s
#   Validating...
#    >> Epoch finished with loss 64.05087 and accuracy 0.000 in 0.8495s
# Epoch 10 of 1000
#   Training...
#    >> Epoch finished with loss 64.05079 and accuracy 0.000 in 1.2494s
#   Validating...
#    >> Epoch finished with loss 64.05087 and accuracy 0.000 in 0.7776s
# Epoch 11 of 1000
#   Training...
#    >> Epoch finished with loss 64.05077 and accuracy 0.000 in 1.2485s
#   Validating...
#    >> Epoch finished with loss 64.05086 and accuracy 0.000 in 0.7270s
# Epoch 12 of 1000
#   Training...
#    >> Epoch finished with loss 64.05076 and accuracy 0.000 in 1.2698s
#   Validating...
#    >> Epoch finished with loss 64.05085 and accuracy 0.000 in 0.8185s
# Epoch 13 of 1000
#   Training...
#    >> Epoch finished with loss 64.05074 and accuracy 0.000 in 1.3069s
#   Validating...
#    >> Epoch finished with loss 64.05084 and accuracy 0.000 in 0.7582s
# Epoch 14 of 1000
#   Training...
#    >> Epoch finished with loss 64.05071 and accuracy 0.000 in 1.2913s
#   Validating...
#    >> Epoch finished with loss 64.05083 and accuracy 0.000 in 0.7962s
# Epoch 15 of 1000
#   Training...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d581b70>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 64.05068 and accuracy 0.000 in 1.1176s
#   Validating...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d5865c0>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 494, in Client
#     deliver_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 722, in deliver_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
#    >> Epoch finished with loss 64.05083 and accuracy 0.000 in 0.6021s
# Epoch 16 of 1000
#   Training...
#    >> Epoch finished with loss 64.05068 and accuracy 0.000 in 1.3464s
#   Validating...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d5812e8>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 64.05082 and accuracy 0.000 in 0.6299s
# Epoch 17 of 1000
#   Training...
#    >> Epoch finished with loss 64.05066 and accuracy 0.000 in 1.3160s
#   Validating...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d5812e8>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 64.05081 and accuracy 0.000 in 0.5949s
# Epoch 18 of 1000
#   Training...
#    >> Epoch finished with loss 64.05064 and accuracy 0.000 in 1.1405s
#   Validating...
#    >> Epoch finished with loss 64.05080 and accuracy 0.000 in 0.7320s
# Epoch 19 of 1000
#   Training...
#    >> Epoch finished with loss 64.05061 and accuracy 0.000 in 1.2662s
#   Validating...
#    >> Epoch finished with loss 64.05080 and accuracy 0.000 in 0.7335s
# Epoch 20 of 1000
#   Training...
#    >> Epoch finished with loss 64.05059 and accuracy 0.000 in 1.2990s
#   Validating...
#    >> Epoch finished with loss 64.05079 and accuracy 0.000 in 0.8004s
# Epoch 21 of 1000
#   Training...
#    >> Epoch finished with loss 64.05056 and accuracy 0.000 in 1.2696s
#   Validating...
#    >> Epoch finished with loss 64.05077 and accuracy 0.000 in 0.7327s
# Epoch 22 of 1000
#   Training...
#    >> Epoch finished with loss 64.05051 and accuracy 0.000 in 1.1846s
#   Validating...
#    >> Epoch finished with loss 64.05077 and accuracy 0.000 in 0.7646s
# Epoch 23 of 1000
#   Training...
#    >> Epoch finished with loss 64.05049 and accuracy 0.000 in 1.3353s
#   Validating...
#    >> Epoch finished with loss 64.05076 and accuracy 0.000 in 0.7216s
# Epoch 24 of 1000
#   Training...
#    >> Epoch finished with loss 64.05048 and accuracy 0.000 in 1.2428s
#   Validating...
#    >> Epoch finished with loss 64.05074 and accuracy 0.000 in 0.7786s
# Epoch 25 of 1000
#   Training...
#    >> Epoch finished with loss 64.05045 and accuracy 0.000 in 1.3239s
#   Validating...
#    >> Epoch finished with loss 64.05073 and accuracy 0.000 in 0.7560s
# Epoch 26 of 1000
#   Training...
#    >> Epoch finished with loss 64.05042 and accuracy 0.000 in 1.3217s
#   Validating...
#    >> Epoch finished with loss 64.05071 and accuracy 0.000 in 0.7599s
# Epoch 27 of 1000
#   Training...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d581978>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 64.05039 and accuracy 0.000 in 1.1236s
#   Validating...
#    >> Epoch finished with loss 64.05070 and accuracy 0.000 in 0.7581s
# Epoch 28 of 1000
#   Training...
#    >> Epoch finished with loss 64.05034 and accuracy 0.000 in 1.3136s
#   Validating...
#    >> Epoch finished with loss 64.05069 and accuracy 0.000 in 0.8190s
# Epoch 29 of 1000
#   Training...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9f38cf60>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 64.05030 and accuracy 0.000 in 1.1124s
#   Validating...
#    >> Epoch finished with loss 64.05067 and accuracy 0.000 in 0.7378s
# Epoch 30 of 1000
#   Training...
#    >> Epoch finished with loss 64.05026 and accuracy 0.000 in 1.2808s
#   Validating...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff4758ad30>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 64.05066 and accuracy 0.000 in 0.6417s
# Epoch 31 of 1000
#   Training...
#    >> Epoch finished with loss 64.05021 and accuracy 0.000 in 1.3333s
#   Validating...
#    >> Epoch finished with loss 64.05064 and accuracy 0.000 in 0.7664s
# Epoch 32 of 1000
#   Training...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d5810f0>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 64.05016 and accuracy 0.000 in 1.1472s
#   Validating...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d581b70>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 64.05063 and accuracy 0.000 in 0.5942s
# Epoch 33 of 1000
#   Training...
#    >> Epoch finished with loss 64.05011 and accuracy 0.000 in 1.2045s
#   Validating...
#    >> Epoch finished with loss 64.05061 and accuracy 0.000 in 0.8265s
# Epoch 34 of 1000
#   Training...
#    >> Epoch finished with loss 64.05007 and accuracy 0.000 in 1.2959s
#   Validating...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9f38cdd8>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 64.05058 and accuracy 0.000 in 0.5785s
# Epoch 35 of 1000
#   Training...
#    >> Epoch finished with loss 64.05000 and accuracy 0.000 in 1.3630s
#   Validating...
#    >> Epoch finished with loss 64.05056 and accuracy 0.000 in 0.7296s
# Epoch 36 of 1000
#   Training...
#    >> Epoch finished with loss 64.04993 and accuracy 0.000 in 1.3474s
#   Validating...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9f38cc50>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 64.05052 and accuracy 0.000 in 0.5989s
# Epoch 37 of 1000
#   Training...
#    >> Epoch finished with loss 64.04990 and accuracy 0.000 in 1.1738s
#   Validating...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9f38cc50>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 64.05050 and accuracy 0.000 in 0.5966s
# Epoch 38 of 1000
#   Training...
#    >> Epoch finished with loss 64.04977 and accuracy 0.000 in 1.1486s
#   Validating...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d581ac8>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 64.05047 and accuracy 0.000 in 0.6046s
# Epoch 39 of 1000
#   Training...
#    >> Epoch finished with loss 64.04973 and accuracy 0.000 in 1.1395s
#   Validating...
#    >> Epoch finished with loss 64.05043 and accuracy 0.000 in 0.7951s
# Epoch 40 of 1000
#   Training...
#    >> Epoch finished with loss 64.04958 and accuracy 0.000 in 1.3267s
#   Validating...
#    >> Epoch finished with loss 64.05038 and accuracy 0.000 in 0.8086s
# Epoch 41 of 1000
#   Training...
#    >> Epoch finished with loss 64.04944 and accuracy 0.000 in 1.3208s
#   Validating...
#    >> Epoch finished with loss 64.05032 and accuracy 0.000 in 0.7646s
# Epoch 42 of 1000
#   Training...
#    >> Epoch finished with loss 64.04933 and accuracy 0.000 in 1.2291s
#   Validating...
#    >> Epoch finished with loss 64.05027 and accuracy 0.000 in 0.7312s
# Epoch 43 of 1000
#   Training...
#    >> Epoch finished with loss 64.04920 and accuracy 0.000 in 1.3224s
#   Validating...
#    >> Epoch finished with loss 64.05021 and accuracy 0.000 in 0.7400s
# Epoch 44 of 1000
#   Training...
#    >> Epoch finished with loss 64.04897 and accuracy 0.000 in 1.1318s
#   Validating...
#    >> Epoch finished with loss 64.05013 and accuracy 0.000 in 0.7339s
# Epoch 45 of 1000
#   Training...
#    >> Epoch finished with loss 64.04874 and accuracy 0.000 in 1.2739s
#   Validating...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff4758a978>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 64.05003 and accuracy 0.000 in 0.6430s
# Epoch 46 of 1000
#   Training...
#    >> Epoch finished with loss 64.04854 and accuracy 0.000 in 1.3370s
#   Validating...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d586470>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 64.04990 and accuracy 0.000 in 0.5953s
# Epoch 47 of 1000
#   Training...
#    >> Epoch finished with loss 64.04810 and accuracy 0.000 in 1.2499s
#   Validating...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d5812e8>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 64.04973 and accuracy 0.000 in 0.6149s
# Epoch 48 of 1000
#   Training...
#    >> Epoch finished with loss 64.04758 and accuracy 0.000 in 1.3507s
#   Validating...
#    >> Epoch finished with loss 64.04948 and accuracy 0.000 in 0.7348s
# Epoch 49 of 1000
#   Training...
#    >> Epoch finished with loss 64.04687 and accuracy 0.000 in 1.3267s
#   Validating...
#    >> Epoch finished with loss 64.04910 and accuracy 0.000 in 0.7669s
# Epoch 50 of 1000
#   Training...
#    >> Epoch finished with loss 64.04556 and accuracy 0.000 in 1.2941s
#   Validating...
#    >> Epoch finished with loss 64.04842 and accuracy 0.000 in 0.7255s
# Epoch 51 of 1000
#   Training...
#    >> Epoch finished with loss 64.04395 and accuracy 0.000 in 1.1256s
#   Validating...
#    >> Epoch finished with loss 64.04697 and accuracy 0.000 in 0.7983s
# Epoch 52 of 1000
#   Training...
#    >> Epoch finished with loss 64.03860 and accuracy 0.000 in 1.3060s
#   Validating...
#    >> Epoch finished with loss 64.03983 and accuracy 0.000 in 0.8391s
# Epoch 53 of 1000
#   Training...
#    >> Epoch finished with loss 64.01260 and accuracy 0.000 in 1.2455s
#   Validating...
#    >> Epoch finished with loss 63.21645 and accuracy 0.000 in 0.7526s
# Epoch 54 of 1000
#   Training...
#    >> Epoch finished with loss 63.11837 and accuracy 0.000 in 1.3579s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.8002s
# Epoch 55 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.3282s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7354s
# Epoch 56 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.2751s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7325s
# Epoch 57 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.2579s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7645s
# Epoch 58 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.2778s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.8032s
# Epoch 59 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.2908s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7443s
# Epoch 60 of 1000
#   Training...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9f38cf60>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.1136s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.8165s
# Epoch 61 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.3626s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7351s
# Epoch 62 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.2704s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.8259s
# Epoch 63 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.2765s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.8245s
# Epoch 64 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.3358s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7422s
# Epoch 65 of 1000
#   Training...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d5812e8>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.1561s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7440s
# Epoch 66 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.3084s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7542s
# Epoch 67 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.3041s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7655s
# Epoch 68 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.2927s
#   Validating...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d581ac8>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.6026s
# Epoch 69 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.2513s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.8281s
# Epoch 70 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.2827s
#   Validating...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d5810f0>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
# ...
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 737, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.6077s
# Epoch 237 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.2489s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7220s
# Epoch 238 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.1201s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7370s
# Epoch 239 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.1248s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.8276s
# Epoch 240 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.2652s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7656s
# Epoch 241 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.3405s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7682s
# Epoch 242 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.2512s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7545s
# Epoch 243 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.3801s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7518s
# Epoch 244 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.3275s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7305s
# Epoch 245 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.2791s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7401s
# Epoch 246 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.1703s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.8154s
# Epoch 247 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.1523s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7471s
# Epoch 248 of 1000
#   Training...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d586940>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 494, in Client
#     deliver_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 722, in deliver_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.1599s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7287s
# Epoch 249 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.3187s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7343s
# Epoch 250 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.2025s
#   Validating...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff4758ac50>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.5724s
# Epoch 251 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.2470s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7767s
# Epoch 252 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.2618s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7859s
# Epoch 253 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.2940s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7629s
# Epoch 254 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.3227s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7294s
# Epoch 255 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.2328s
#   Validating...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.7419s
# Epoch 256 of 1000
#   Training...
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 1.2539s
#   Validating...
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7eff9d581978>>
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 349, in __del__
#     self._shutdown_workers()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 328, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 345, in get
#     return ForkingPickler.loads(res)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/multiprocessing/reductions.py", line 70, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.5/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
#    >> Epoch finished with loss 63.05553 and accuracy 0.000 in 0.6585s
# Epoch 257 of 1000
#   Training...
# Process Process-4091:
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# Process Process-4092:
# Process Process-4090:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process Process-4089:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#     r = index_queue.get()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#     r = index_queue.get()
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#     r = index_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 343, in get
#     res = self._reader.recv_bytes()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 343, in get
#     res = self._reader.recv_bytes()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 343, in get
#     res = self._reader.recv_bytes()
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/ubuntu/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#     r = index_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 343, in get
#     res = self._reader.recv_bytes()
# KeyboardInterrupt
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-f755bce09112> in <module>()
# ----> 1 trained_model, statistics = trainer.train(train_dataset, val_dataset, save_every=50000, learnrate=10, collate_fn=collate, e_break=1, epoch=1000)
#
# ~/dotCuda/notebook/trainer.py in train(self, train_dataset, val_dataset, epoch, batch_size, learnrate, collate_fn, e_break, save_every)
#      44             print('Epoch {} of {}'.format(e, epoch))
#      45             print('  Training...')
# ---> 46             self.model, train_loss, train_acc = self.train_epoch(train_loader, optimizer=sgd_optimizer, e_break=e_break)
#      47             self.statistics['train-losses'].append(train_loss)
#      48             self.statistics['train-accuracy'].append(train_acc)
#
# ~/dotCuda/notebook/trainer.py in train_epoch(self, dataloader, optimizer, mode, print_every, e_break)
#      95             if mode == 'train':
#      96                 optimizer.zero_grad()
# ---> 97                 total_loss.backward()
#      98                 optimizer.step()
#      99
#
# ~/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#      91                 products. Defaults to ``False``.
#      92         """
# ---> 93         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#      94
#      95     def register_hook(self, hook):
#
# ~/virtuals/pytorch-cu90-0.4.0/lib/python3.5/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      87     Variable._execution_engine.run_backward(
#      88         tensors, grad_tensors, retain_graph, create_graph,
# ---> 89         allow_unreachable=True)  # allow_unreachable flag
#      90
#      91
#
# KeyboardInterrupt:

# %%
trainer.plot_over_epoch()

# %%
import random

for idx in range(8):#[random.randint(0, 8) for i in range(8)]:
    print('\nqn no', idx)
    qns, img, ans = collate([train_dataset[idx]])
    output = model(img.cuda(), qns.long().cuda())
    _, pred = output.topk(10)
    # print(qns, pred)

    #pil_img = transforms.ToPILImage()(img)
    #plt.imshow(pil_img)
    qnss = ' '.join([vocab.idx2word[i.item()] for i in qns.data])
    ans_ = ' / '.join([answers.idx2ans[j.item()] for j in pred[0]])
    lbl = ' - '.join([answers.idx2ans[k.item()] for k in ans[0]])
    print('question:', qnss)
    print('answer:', ans_)
    print('label:', lbl)
    ans = [a.cuda() for a in ans]
    print('accuracy', trainer.accuracy_fn(output.detach(), ans))
    print('loss', trainer.get_losses(output, ans))
# Out:
# qn no 0
# question: <start> what is this photo taken looking through ? <end>
# answer: white / orange / skiing / yes / pitcher / net / red / riding motorcycle / catcher / city street
# label: net - net - net - net - net - mesh - net - net - net
# accuracy 0.0
# loss tensor(8.0069, device='cuda:0')
#
# qn no 1
# question: <start> what position is this man playing ? <end>
# answer: white / orange / skiing / yes / pitcher / net / red / riding motorcycle / catcher / city street
# label: pitcher - catcher - pitcher - pitcher - pitcher - pitcher - pitcher - pitcher - pitcher - pitcher
# accuracy 0.0
# loss tensor(8.0069, device='cuda:0')
#
# qn no 2
# question: <start> what color is the players shirt ? <end>
# answer: white / orange / skiing / yes / pitcher / net / red / riding motorcycle / catcher / city street
# label: orange - orange - orange - orange - orange - orange - orange - orange - orange - orange
# accuracy 0.0
# loss tensor(8.0069, device='cuda:0')
#
# qn no 3
# question: <start> is this man a professional baseball player ? <end>
# answer: white / orange / skiing / yes / pitcher / net / red / riding motorcycle / catcher / bleachers
# label: yes - yes - yes - yes - yes - no - yes - yes - yes - yes
# accuracy 0.0
# loss tensor(8.0069, device='cuda:0')
#
# qn no 4
# question: <start> what color is the snow ? <end>
# answer: white / orange / skiing / yes / pitcher / net / red / riding motorcycle / catcher / city street
# label: white - white - white - white - white - white - white - white - white - white
# accuracy 1.0
# loss tensor(7.0069, device='cuda:0')
#
# qn no 5
# question: <start> what is the person doing ? <end>
# answer: white / orange / skiing / yes / pitcher / net / red / riding motorcycle / catcher / city street
# label: skiing - skiing - skiing - skiing - skiing - skiing - skiing - skiing - skiing - skiing
# accuracy 0.0
# loss tensor(8.0069, device='cuda:0')
#
# qn no 6
# question: <start> what color is the persons headwear ? <end>
# answer: white / orange / skiing / yes / pitcher / net / red / riding motorcycle / city street / catcher
# label: red - red - black - red - red - red - red - red - red and white
# accuracy 0.0
# loss tensor(8.0069, device='cuda:0')
#
# qn no 7
# question: <start> what is in the person 's hand ? <end>
# answer: white / orange / skiing / yes / pitcher / net / red / riding motorcycle / catcher / city street
# label: frisbee - frisbee - frisbie - frisbee - frisbee - frisbee - frisbee - frisbee
# accuracy 0.0
# loss tensor(8.0069, device='cuda:0')
